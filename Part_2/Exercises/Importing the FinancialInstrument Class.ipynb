# %%
import FinancialInstrument as FI

# %%
stock = FI.RiskReturn("TSLA", "2015-01-01", "2022-01-01", False)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stock.plot_prices()

# %%
stock.plot_returns()

# %%
stock.annualized_perf()
# Out:
# 'Annualized Performance for TSLA: Return: 0.455 | Risk 0.549s'
